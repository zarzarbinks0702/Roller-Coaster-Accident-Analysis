# %%
import pandas as pd

# %%
#loading database
work = pd.read_csv("safer-parks-accident-dataset.csv")
work.head()
# Out:
#     acc_id    acc_date acc_state    acc_city fix_port  \
# 0  1007272  2009-04-05        CA     Anaheim        F
# 1   918972  2009-02-05        FL      Naples        P
# 2   919123  2008-11-08        CA  Buena Park        F
# 3   919095  2008-11-01        CA     Anaheim        F
# 4   919094  2008-10-29        CA     Anaheim        F
#
#                                               source            bus_type  \
# 0  California Division of Occupational Safety and...      Amusement park
# 1                       Florida Dept. of Agriculture  Carnival or rental
# 2  California Division of Occupational Safety and...      Amusement park
# 3  California Division of Occupational Safety and...      Amusement park
# 4  California Division of Occupational Safety and...      Amusement park
#
#   industry_sector     device_category         device_type  ... gender  \
# 0  amusement ride  cars & track rides          Track ride  ...      F
# ...

# %%
# creating a dataframe to reduce database size
work_df = pd.DataFrame(work, columns = ["acc_id", "acc_date", "acc_state","acc_city", "industry_sector", "device_type", "num_injured"])

# %%
work_df.head()
# Out:
#     acc_id    acc_date acc_state    acc_city industry_sector  \
# 0  1007272  2009-04-05        CA     Anaheim  amusement ride
# 1   918972  2009-02-05        FL      Naples  amusement ride
# 2   919123  2008-11-08        CA  Buena Park  amusement ride
# 3   919095  2008-11-01        CA     Anaheim  amusement ride
# 4   919094  2008-10-29        CA     Anaheim  amusement ride
#
#           device_type  num_injured
# 0          Track ride            1
# 1  Flying carpet ride            1
# 2     Coaster - steel            1
# 3  Spinning cups/tubs            1
# 4  Spinning cups/tubs            1

# %%
# exporting dataframe into csv for table vizual use
work_df.to_csv("reduced_data_frame.csv")
